# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/home/diablo/Desktop/IIIT_Program/Module2 - Main EDA /Bivariate Analysis/currencies.csv")
df.head()
# Out:
#         Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0  July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1  July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2  July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3  July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4  July 08, 2016       9.31350  1.25797       140.510              1.07261
#
#    U.S. Dollar  Algerian Dinar  Australian Dollar  Bahrain Dinar  \
# 0      1.39596             NaN            1.87126       0.524882
# 1      1.39684         154.063            1.85825       0.525213
# 2      1.39286         154.094            1.87313       0.523717
# 3      1.39316         153.957            1.85236       0.523829
# 4      1.39257         154.062            1.85974       0.523607
#
#    Botswana Pula  ...  South African Rand  Sri Lanka Rupee  Swedish Krona  \
# ...

# %%
df.dtypes
# Out:
# Currency                       object
# Chinese Yuan                  float64
# Euro                          float64
# Japanese Yen                  float64
# U.K. Pound Sterling           float64
# U.S. Dollar                   float64
# Algerian Dinar                float64
# Australian Dollar             float64
# Bahrain Dinar                 float64
# Botswana Pula                 float64
# Brazilian Real                float64
# Brunei Dollar                 float64
# Canadian Dollar               float64
# Chilean Peso                  float64
# Colombian Peso                 object
# Czech Koruna                  float64
# Danish Krone                  float64
# Hungarian Forint              float64
# Icelandic Krona               float64
# Indian Rupee                  float64
# Indonesian Rupiah              object
# Iranian Rial                   object
# Israeli New Sheqel            float64
# Kazakhstani Tenge             float64
# Korean Won                     object
# ...

# %%
df1=df.drop("Currency",axis=1)
df1.head()
# Out:
#    Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  U.S. Dollar  \
# 0       9.29446  1.25367       143.645              1.05054      1.39596
# 1       9.31515  1.25322       142.715              1.06143      1.39684
# 2       9.31697  1.25834       140.540              1.07300      1.39286
# 3       9.31315  1.25737       140.640              1.06911      1.39316
# 4       9.31350  1.25797       140.510              1.07261      1.39257
#
#    Algerian Dinar  Australian Dollar  Bahrain Dinar  Botswana Pula  \
# 0             NaN            1.87126       0.524882            NaN
# 1         154.063            1.85825       0.525213        15.2162
# 2         154.094            1.87313       0.523717        15.2392
# 3         153.957            1.85236       0.523829        15.1430
# 4         154.062            1.85974       0.523607        15.1202
#
#    Brazilian Real  ...  South African Rand  Sri Lanka Rupee  Swedish Krona  \
# ...

# %%
df1.isnull().sum()
# Out:
# Chinese Yuan                  0
# Euro                          0
# Japanese Yen                  1
# U.K. Pound Sterling           0
# U.S. Dollar                   0
# Algerian Dinar                2
# Australian Dollar             0
# Bahrain Dinar                 0
# Botswana Pula                 2
# Brazilian Real                0
# Brunei Dollar                 1
# Canadian Dollar               1
# Chilean Peso                  0
# Colombian Peso                0
# Czech Koruna                  3
# Danish Krone                  0
# Hungarian Forint              0
# Icelandic Krona               0
# Indian Rupee                  2
# Indonesian Rupiah             4
# Iranian Rial                  5
# Israeli New Sheqel            0
# Kazakhstani Tenge             3
# Korean Won                    0
# Kuwaiti Dinar                 5
# Libyan Dinar                  0
# Malaysian Ringgit             3
# Mauritian Rupee               2
# Mexican Peso                  0
# ...

# %%
df1.shape
# Out:
# (11, 51)

# %%
df1.drop("Pakistani Rupee",axis=1,inplace=True)

# %%
df1.drop("Tunisian Dinar",axis=1,inplace=True)
df1.drop("Peso Uruguayo",axis=1,inplace=True)

# %%
df1.drop("Kuwaiti Dinar",axis=1,inplace=True)

# %%
df1.shape
# Out:
# (11, 47)

# %%
df1.dtypes
# Out:
# Chinese Yuan                  float64
# Euro                          float64
# Japanese Yen                  float64
# U.K. Pound Sterling           float64
# U.S. Dollar                   float64
# Algerian Dinar                float64
# Australian Dollar             float64
# Bahrain Dinar                 float64
# Botswana Pula                 float64
# Brazilian Real                float64
# Brunei Dollar                 float64
# Canadian Dollar               float64
# Chilean Peso                  float64
# Colombian Peso                 object
# Czech Koruna                  float64
# Danish Krone                  float64
# Hungarian Forint              float64
# Icelandic Krona               float64
# Indian Rupee                  float64
# Indonesian Rupiah              object
# Iranian Rial                   object
# Israeli New Sheqel            float64
# Kazakhstani Tenge             float64
# Korean Won                     object
# Libyan Dinar                  float64
# ...

# %%
df1["Colombian Peso"]
# Out:
# 0     4,074.83
# 1     4,070.93
# 2     4,132.44
# 3     4,183.94
# 4     4,158.90
# 5     4,103.04
# 6     4,078.10
# 7     4,053.18
# 8     4,085.35
# 9     4,074.53
# 10    4,060.19
# Name: Colombian Peso, dtype: object

# %%
df1["Colombian Peso"]=df["Colombian Peso"].str.replace(",","").astype(float)

# %%
df1["Colombian Peso"].dtypes
# Out:
# dtype('float64')

# %%
df1.dtypes
# Out:
# Chinese Yuan                  float64
# Euro                          float64
# Japanese Yen                  float64
# U.K. Pound Sterling           float64
# U.S. Dollar                   float64
# Algerian Dinar                float64
# Australian Dollar             float64
# Bahrain Dinar                 float64
# Botswana Pula                 float64
# Brazilian Real                float64
# Brunei Dollar                 float64
# Canadian Dollar               float64
# Chilean Peso                  float64
# Colombian Peso                float64
# Czech Koruna                  float64
# Danish Krone                  float64
# Hungarian Forint              float64
# Icelandic Krona               float64
# Indian Rupee                  float64
# Indonesian Rupiah              object
# Iranian Rial                   object
# Israeli New Sheqel            float64
# Kazakhstani Tenge             float64
# Korean Won                     object
# Libyan Dinar                  float64
# ...

# %%
df1.drop("Iranian Rial",axis=1,inplace=True)

# %%
df1.dtypes
# Out:
# Chinese Yuan                  float64
# Euro                          float64
# Japanese Yen                  float64
# U.K. Pound Sterling           float64
# U.S. Dollar                   float64
# Algerian Dinar                float64
# Australian Dollar             float64
# Bahrain Dinar                 float64
# Botswana Pula                 float64
# Brazilian Real                float64
# Brunei Dollar                 float64
# Canadian Dollar               float64
# Chilean Peso                  float64
# Colombian Peso                float64
# Czech Koruna                  float64
# Danish Krone                  float64
# Hungarian Forint              float64
# Icelandic Krona               float64
# Indian Rupee                  float64
# Indonesian Rupiah              object
# Israeli New Sheqel            float64
# Kazakhstani Tenge             float64
# Korean Won                     object
# Libyan Dinar                  float64
# Malaysian Ringgit             float64
# ...

# %%
df1["Korean Won"]
# Out:
# 0     1,608.98
# 1     1,603.72
# 2     1,605.97
# 3     1,624.15
# 4     1,610.65
# 5     1,610.85
# 6     1,597.66
# 7     1,599.74
# 8     1,593.92
# 9     1,591.58
# 10    1,573.13
# Name: Korean Won, dtype: object

# %%
df1["Indonesian Rupiah"]=df["Indonesian Rupiah"].str.replace(",","").astype(float)
df1["Korean Won"]=df["Korean Won"].str.replace(",","").astype(float)

# %%
df1.dtypes
# Out:
# Chinese Yuan                  float64
# Euro                          float64
# Japanese Yen                  float64
# U.K. Pound Sterling           float64
# U.S. Dollar                   float64
# Algerian Dinar                float64
# Australian Dollar             float64
# Bahrain Dinar                 float64
# Botswana Pula                 float64
# Brazilian Real                float64
# Brunei Dollar                 float64
# Canadian Dollar               float64
# Chilean Peso                  float64
# Colombian Peso                float64
# Czech Koruna                  float64
# Danish Krone                  float64
# Hungarian Forint              float64
# Icelandic Krona               float64
# Indian Rupee                  float64
# Indonesian Rupiah             float64
# Israeli New Sheqel            float64
# Kazakhstani Tenge             float64
# Korean Won                    float64
# Libyan Dinar                  float64
# Malaysian Ringgit             float64
# ...

# %%
df1.head()
# Out:
#    Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  U.S. Dollar  \
# 0       9.29446  1.25367       143.645              1.05054      1.39596
# 1       9.31515  1.25322       142.715              1.06143      1.39684
# 2       9.31697  1.25834       140.540              1.07300      1.39286
# 3       9.31315  1.25737       140.640              1.06911      1.39316
# 4       9.31350  1.25797       140.510              1.07261      1.39257
#
#    Algerian Dinar  Australian Dollar  Bahrain Dinar  Botswana Pula  \
# 0             NaN            1.87126       0.524882            NaN
# 1         154.063            1.85825       0.525213        15.2162
# 2         154.094            1.87313       0.523717        15.2392
# 3         153.957            1.85236       0.523829        15.1430
# 4         154.062            1.85974       0.523607        15.1202
#
#    Brazilian Real  ...  Saudi Arabian Riyal  Singapore Dollar  \
# ...

# %%
df1.corr()
# Out:
#                             Chinese Yuan      Euro  Japanese Yen  \
# Chinese Yuan                    1.000000  0.151596      0.117566
# Euro                            0.151596  1.000000     -0.645719
# Japanese Yen                    0.117566 -0.645719      1.000000
# U.K. Pound Sterling             0.108695  0.531150     -0.970308
# U.S. Dollar                     0.291582 -0.210587      0.210295
# Algerian Dinar                  0.815216  0.259964     -0.388099
# Australian Dollar               0.077983  0.331588     -0.582032
# Bahrain Dinar                   0.291926 -0.209926      0.209957
# Botswana Pula                   0.467693  0.469668     -0.627015
# Brazilian Real                  0.320508  0.383645     -0.641122
# Brunei Dollar                   0.499400  0.103766     -0.260258
# Canadian Dollar                -0.186643  0.638422     -0.662233
# Chilean Peso                    0.028821  0.242743     -0.809751
# ...

# %%
df_corr=df1.corr()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df_corr, cmap="coolwarm")
plt.title("Correlation heat-map")
plt.tight_layout()
plt.show()

# %%
df_corr["Japanese Yen"].sort_values()

# With this you can find how Japanese yen correlates with Other currencies

#You can also use this to hedge Japanese Yen with UK Pound  as they negatively correlate
# Out:
# U.K. Pound Sterling          -0.970308
# Icelandic Krona              -0.834549
# Norwegian Krone              -0.818583
# Chilean Peso                 -0.809751
# Polish Zloty                 -0.806694
# Israeli New Sheqel           -0.798265
# Korean Won                   -0.796719
# Russian Ruble                -0.774645
# Colombian Peso               -0.725137
# Danish Krone                 -0.668736
# Canadian Dollar              -0.662233
# Euro                         -0.645719
# Brazilian Real               -0.641122
# South African Rand           -0.629790
# Czech Koruna                 -0.629068
# Botswana Pula                -0.627015
# Malaysian Ringgit            -0.602250
# Nepalese Rupee               -0.602069
# Australian Dollar            -0.582032
# Hungarian Forint             -0.572344
# Mexican Peso                 -0.497609
# Swedish Krona                -0.484786
# Thai Baht                    -0.458043
# Algerian Dinar               -0.388099
# ...
